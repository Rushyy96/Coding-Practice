# %% [markdown]
# All data in this page sourced from - https://data.cms.gov/provider-data/search?theme=Nursing%20homes%20including%20rehab%20services
# 2 datasets - Provider info + Owner info

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('NewUSAproviderinfo.csv', header= 0,
                        encoding= 'unicode_escape')

# %%
x = range(33,89,1)
list_1 = list(x)

# %%
list_2 = [0,2,6,7,11,12,13,14,16,17,18,19,20,22,23,25,27,29,31,33,34,35,36,37]

# %%
list_3 = list_1 + list_2

# %%
df.drop(df.columns[(list_3)], axis=1, inplace=True)

# %%
df = df.reset_index()

# %%
df = df.drop(columns={'index'})

# %%
df.head(5)
# Out:
#                                  Provider Name Provider City Provider State  \
# 0                     BURNS NURSING HOME, INC.  RUSSELLVILLE             AL
# 1               COOSA VALLEY HEALTHCARE CENTER     SYLACAUGA             AL
# 2                   HIGHLANDS HEALTH AND REHAB    SCOTTSBORO             AL
# 3  EASTVIEW REHABILITATION & HEALTHCARE CENTER    BIRMINGHAM             AL
# 4                PLANTATION MANOR NURSING HOME      MC CALLA             AL
#
#    Provider Zip Code Provider County Name            Ownership Type  \
# 0              35653             Franklin  For profit - Corporation
# 1              35150            Talladega  For profit - Corporation
# 2              35768              Jackson       Government - County
# 3              35206            Jefferson   For profit - Individual
# 4              35111            Jefferson   For profit - Individual
#
#    Number of Certified Beds                 Legal Business Name  \
# ...

# %%
df.to_csv('Clean_USA_Provider_Info.csv')
