# %%
import requests

# %%
data = requests.get("https://api.cqc.org.uk/public/v1/locations/1-12130228820").text

# %%
print(data)
# Out:
# {
#   "locationId": "1-12130228820",
#   "providerId": "1-11456119333",
#   "organisationType": "Location",
#   "type": "Primary Dental Care",
#   "name": "Smiles on Harrogate Road",
#   "onspdCcgCode": "E38000225",
#   "onspdCcgName": "NHS Leeds CCG",
#   "onspdIcbCode": "E54000054",
#   "onspdIcbName": "NHS West Yorkshire Integrated Care Board",
#   "uprn": "72090798",
#   "registrationStatus": "Registered",
#   "registrationDate": "2021-12-10",
#   "dormancy": "N",
#   "numberOfBeds": 0,
#   "postalAddressLine1": "41 Harrogate Road",
#   "postalAddressTownCity": "Leeds",
#   "region": "Yorkshire & Humberside",
#   "postalCode": "LS7 3PD",
#   "onspdLatitude": 53.8283292,
#   "onspdLongitude": -1.5377528,
#   "careHome": "N",
#   "inspectionDirectorate": "Primary medical services",
#   "mainPhoneNumber": "01133000202",
#   "constituency": "Leeds North East",
#   "localAuthority": "Leeds",
#   "relationships": [
#
#   ],
#   "locationTypes": [
#
#   ],
#   "regulatedActivities": [
# ...
