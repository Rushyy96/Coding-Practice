# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("CleanCQCServicesNew - Copy.csv")

# %%
df2 = pd.read_csv("care-homes.csv")
# Out:
# C:\Users\jackr\AppData\Local\Temp\ipykernel_15328\2676207111.py:1: DtypeWarning: Columns (20,44,76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("care-homes.csv")

# %%
df3 = pd.merge(df1, df2, how="left", left_on=['Location Name', 'Care homes beds', 'Location Postal Code'], right_on=['Company name', 'Beds', 'Postal Code'])

# %%
df3.head()
# Out:
#    Unnamed: 0 Location HSCA start date                 Location Name  \
# 0           0               11/12/2020                  Henley House
# 1           1               18/12/2020               Charlotte House
# 2           2               18/12/2020           Regency Care Centre
# 3           3               12/12/2013  Kingswood House Nursing Home
# 4           4               04/11/2013                  Little Haven
#
#    Location Telephone Number Registered Manager_x Location Web Address  \
# 0                        NaN                    *                  NaN
# 1               1.516431e+09      Richards, Clare                  NaN
# 2               1.617962e+09     Birkett, Nichola                  NaN
# 3               1.424716e+09     Garner, Danielle                  NaN
# 4               2.084613e+09      Muriuki, Martin                  NaN
#
#    Care homes beds Location Latest Overall Rating Publication Date  \
# ...

# %%
df3.to_csv('CombinedCareHomeData.csv')
